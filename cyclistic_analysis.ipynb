# %% [markdown]
# ## Who Uses Cyclistic: Members vs Casuals
#
# ### Business Task:
# The goal of this analysis is to explore and compare usage patterns between Cyclistic's casual riders and annual members. The objective is to uncover behavioral trends and insights that can inform targeted marketing strategies. The analysis aims to identify key differences in ride frequency, duration, time of day, and trip purpose between these two rider segments. These insights will serve as the foundation for a strategic initiative to convert casual riders into long-term members, contributing to Cyclistic’s growth and profitability.
#
# ### Data Source:
#
# For this analysis, I utilized publicly available historical trip data provided by Motivate International Inc. under a permissive license for educational and analytical purposes. Specifically, I worked with the **Divvy 2019 Q1** and **Divvy 2020 Q1** datasets. These datasets represent anonymized bike-share trip logs for Chicago’s Divvy system, which is used here to simulate Cyclistic’s operations.
#
# The Divvy 2019 Q1 dataset contains structured records including:
# - Ride identifiers (trip_id)
# - Timestamps (start_time, end_time) in the format yyyy-mm-dd hh:mm:ss
# - User details (usertype: subscriber or customer, gender, birthyear)
# - Bike identifier (bikeid)
# - Origin station details (from_station_id, from_station_name)
# - Destination station details (to_station_id, to_station_name)
# - Trip duration (tripduration) in seconds
#
# The Divvy 2020 Q1 dataset contains structured records including:
# - Ride identifiers (ride_id, rideable_type)
# - Timestamps (started_at, ended_at) in the format yyyy-mm-dd hh:mm:ss
# - User details (member_casual: member or casual)
# - Origin station details (start_station_id, start_station_name, start_lat, start_lng)
# - Destination station details (end_station_id, end_station_name, end_lat, end_lng)
#
# All personally identifiable information has been excluded to preserve privacy and security.

# %% [markdown]
# ### Data Preparation:
#
# Install *tidyverse*, *conflicted*, and *scales* libraries. *tidyverse* is a collection of R packages for data science workflows. It includes *ggplot2* for visualization, *dplyr* for data wrangling, *tidyr* for tidying data, *readr* for reading CSVs, *purrr* for functional programming, and *tibble* for modern data frames. *conflicted*, on the other hand, is a library that helps manage namespace conflicts between R packages. *scales* provides functions and formatting tools for data visualization.

# %%
install.packages("tidyverse")
install.packages("conflicted")
install.packages("scales")
# Out:
# Installing package into ‘/home/laballais/R/x86_64-pc-linux-gnu-library/4.1’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/home/laballais/R/x86_64-pc-linux-gnu-library/4.1’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/home/laballais/R/x86_64-pc-linux-gnu-library/4.1’
# (as ‘lib’ is unspecified)

# %% [markdown]
# Load the libraries and set default choices for library conflicts.

# %%
library("tidyverse")
library("conflicted")
library("scales")

conflict_prefer("filter", "dplyr")
conflict_prefer("lag", "dplyr")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# [conflicted] Will prefer dplyr::filter over any other package.
# [conflicted] Will prefer dplyr::lag over any other package.

# %% [markdown]
# Save the Divvy datasets (csv) into dataframes.

# %%
# Datasets are assumed to be located inside a folder named "dataset" which is in the same location as this file. 
q1_2019 <- read_csv("./dataset/Divvy_Trips_2019_Q1.csv")
q1_2020 <- read_csv("./dataset/Divvy_Trips_2020_Q1.csv")
# Out:
# Rows: 365069 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (6): start_time, end_time, from_station_name, to_station_name, usertype,...
# dbl (5): trip_id, bikeid, from_station_id, to_station_id, birthyear
# num (1): tripduration
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 426887 Columns: 13
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (7): ride_id, rideable_type, started_at, ended_at, start_station_name, e...
# dbl (6): start_station_id, end_station_id, start_lat, start_lng, end_lat, en...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# Check the column names of the two dataframes.

# %%
colnames(q1_2019)
colnames(q1_2020)
# Out:
#  [1] "trip_id"           "start_time"        "end_time"
#  [4] "bikeid"            "tripduration"      "from_station_id"
#  [7] "from_station_name" "to_station_id"     "to_station_name"
# [10] "usertype"          "gender"            "birthyear"
#  [1] "ride_id"            "rideable_type"      "started_at"
#  [4] "ended_at"           "start_station_name" "start_station_id"
#  [7] "end_station_name"   "end_station_id"     "start_lat"
# [10] "start_lng"          "end_lat"            "end_lng"
# [13] "member_casual"

# %% [markdown]
# Follow the column names of q1_2020. Rename the column names of q1_2019 and check the two dataframes for inconsistencies.

# %%
q1_2019 <- rename(q1_2019,
                     ride_id = trip_id,
                     rideable_type = bikeid,
                     started_at = start_time,
                     ended_at = end_time,
                     start_station_name = from_station_name,
                     start_station_id = from_station_id,
                     end_station_name = to_station_name,
                     end_station_id = to_station_id,
                     member_casual = usertype
              )

str(q1_2019)
str(q1_2020)
# Out:
# spc_tbl_ [365,069 × 12] (S3: spec_tbl_df/tbl_df/tbl/data.frame)
#  $ ride_id           : num [1:365069] 21742443 21742444 21742445 21742446 21742447 ...
#  $ started_at        : chr [1:365069] "2019-01-01 0:04:37" "2019-01-01 0:08:13" "2019-01-01 0:13:23" "2019-01-01 0:13:45" ...
#  $ ended_at          : chr [1:365069] "2019-01-01 0:11:07" "2019-01-01 0:15:34" "2019-01-01 0:27:12" "2019-01-01 0:43:28" ...
#  $ rideable_type     : num [1:365069] 2167 4386 1524 252 1170 ...
#  $ tripduration      : num [1:365069] 390 441 829 1783 364 ...
#  $ start_station_id  : num [1:365069] 199 44 15 123 173 98 98 211 150 268 ...
#  $ start_station_name: chr [1:365069] "Wabash Ave & Grand Ave" "State St & Randolph St" "Racine Ave & 18th St" "California Ave & Milwaukee Ave" ...
#  $ end_station_id    : num [1:365069] 84 624 644 176 35 49 49 142 148 141 ...
#  $ end_station_name  : chr [1:365069] "Milwaukee Ave & Grand Ave" "Dearborn St & Van Buren St (*)" "Western Ave & Fillmore St (*)" "Clark St & Elm St" ...
#  $ member_casual     : chr [1:365069] "Subscriber" "Subscriber" "Subscriber" "Subscriber" ...
#  $ gender            : chr [1:365069] "Male" "Female" "Female" "Male" ...
#  $ birthyear         : num [1:365069] 1989 1990 1994 1993 1994 ...
#  - attr(*, "spec")=
#   .. cols(
#   ..   trip_id = col_double(),
#   ..   start_time = col_character(),
#   ..   end_time = col_character(),
#   ..   bikeid = col_double(),
#   ..   tripduration = col_number(),
#   ..   from_station_id = col_double(),
#   ..   from_station_name = col_character(),
#   ..   to_station_id = col_double(),
#   ..   to_station_name = col_character(),
#   ..   usertype = col_character(),
#   ..   gender = col_character(),
#   ..   birthyear = col_double()
#   .. )
#  - attr(*, "problems")=<externalptr>
# spc_tbl_ [426,887 × 13] (S3: spec_tbl_df/tbl_df/tbl/data.frame)
#  $ ride_id           : chr [1:426887] "EACB19130B0CDA4A" "8FED874C809DC021" "789F3C21E472CA96" "C9A388DAC6ABF313" ...
#  $ rideable_type     : chr [1:426887] "docked_bike" "docked_bike" "docked_bike" "docked_bike" ...
#  $ started_at        : chr [1:426887] "2020-01-21 20:06:59" "2020-01-30 14:22:39" "2020-01-09 19:29:26" "2020-01-06 16:17:07" ...
#  $ ended_at          : chr [1:426887] "2020-01-21 20:14:30" "2020-01-30 14:26:22" "2020-01-09 19:32:17" "2020-01-06 16:25:56" ...
#  $ start_station_name: chr [1:426887] "Western Ave & Leland Ave" "Clark St & Montrose Ave" "Broadway & Belmont Ave" "Clark St & Randolph St" ...
#  $ start_station_id  : num [1:426887] 239 234 296 51 66 212 96 96 212 38 ...
#  $ end_station_name  : chr [1:426887] "Clark St & Leland Ave" "Southport Ave & Irving Park Rd" "Wilton Ave & Belmont Ave" "Fairbanks Ct & Grand Ave" ...
#  $ end_station_id    : num [1:426887] 326 318 117 24 212 96 212 212 96 100 ...
#  $ start_lat         : num [1:426887] 42 42 41.9 41.9 41.9 ...
#  $ start_lng         : num [1:426887] -87.7 -87.7 -87.6 -87.6 -87.6 ...
#  $ end_lat           : num [1:426887] 42 42 41.9 41.9 41.9 ...
#  $ end_lng           : num [1:426887] -87.7 -87.7 -87.7 -87.6 -87.6 ...
#  $ member_casual     : chr [1:426887] "member" "member" "member" "member" ...
#  - attr(*, "spec")=
#   .. cols(
#   ..   ride_id = col_character(),
#   ..   rideable_type = col_character(),
#   ..   started_at = col_character(),
#   ..   ended_at = col_character(),
#   ..   start_station_name = col_character(),
#   ..   start_station_id = col_double(),
#   ..   end_station_name = col_character(),
#   ..   end_station_id = col_double(),
#   ..   start_lat = col_double(),
#   ..   start_lng = col_double(),
#   ..   end_lat = col_double(),
#   ..   end_lng = col_double(),
#   ..   member_casual = col_character()
#   .. )
#  - attr(*, "problems")=<externalptr>

# %% [markdown]
# *ride_id* and *rideable_type* attributes in the two dataframes are of different datatypes. Convert *ride_id* and *rideable_type* into consistent datatypes for the two dataframes.

# %%
q1_2019 <-  mutate(q1_2019, ride_id = as.character(ride_id), rideable_type = as.character(rideable_type))

str(q1_2019)
str(q1_2020)
# Out:
# tibble [365,069 × 12] (S3: tbl_df/tbl/data.frame)
#  $ ride_id           : chr [1:365069] "21742443" "21742444" "21742445" "21742446" ...
#  $ started_at        : chr [1:365069] "2019-01-01 0:04:37" "2019-01-01 0:08:13" "2019-01-01 0:13:23" "2019-01-01 0:13:45" ...
#  $ ended_at          : chr [1:365069] "2019-01-01 0:11:07" "2019-01-01 0:15:34" "2019-01-01 0:27:12" "2019-01-01 0:43:28" ...
#  $ rideable_type     : chr [1:365069] "2167" "4386" "1524" "252" ...
#  $ tripduration      : num [1:365069] 390 441 829 1783 364 ...
#  $ start_station_id  : num [1:365069] 199 44 15 123 173 98 98 211 150 268 ...
#  $ start_station_name: chr [1:365069] "Wabash Ave & Grand Ave" "State St & Randolph St" "Racine Ave & 18th St" "California Ave & Milwaukee Ave" ...
#  $ end_station_id    : num [1:365069] 84 624 644 176 35 49 49 142 148 141 ...
#  $ end_station_name  : chr [1:365069] "Milwaukee Ave & Grand Ave" "Dearborn St & Van Buren St (*)" "Western Ave & Fillmore St (*)" "Clark St & Elm St" ...
#  $ member_casual     : chr [1:365069] "Subscriber" "Subscriber" "Subscriber" "Subscriber" ...
#  $ gender            : chr [1:365069] "Male" "Female" "Female" "Male" ...
#  $ birthyear         : num [1:365069] 1989 1990 1994 1993 1994 ...
# spc_tbl_ [426,887 × 13] (S3: spec_tbl_df/tbl_df/tbl/data.frame)
#  $ ride_id           : chr [1:426887] "EACB19130B0CDA4A" "8FED874C809DC021" "789F3C21E472CA96" "C9A388DAC6ABF313" ...
#  $ rideable_type     : chr [1:426887] "docked_bike" "docked_bike" "docked_bike" "docked_bike" ...
#  $ started_at        : chr [1:426887] "2020-01-21 20:06:59" "2020-01-30 14:22:39" "2020-01-09 19:29:26" "2020-01-06 16:17:07" ...
#  $ ended_at          : chr [1:426887] "2020-01-21 20:14:30" "2020-01-30 14:26:22" "2020-01-09 19:32:17" "2020-01-06 16:25:56" ...
#  $ start_station_name: chr [1:426887] "Western Ave & Leland Ave" "Clark St & Montrose Ave" "Broadway & Belmont Ave" "Clark St & Randolph St" ...
#  $ start_station_id  : num [1:426887] 239 234 296 51 66 212 96 96 212 38 ...
#  $ end_station_name  : chr [1:426887] "Clark St & Leland Ave" "Southport Ave & Irving Park Rd" "Wilton Ave & Belmont Ave" "Fairbanks Ct & Grand Ave" ...
#  $ end_station_id    : num [1:426887] 326 318 117 24 212 96 212 212 96 100 ...
#  $ start_lat         : num [1:426887] 42 42 41.9 41.9 41.9 ...
#  $ start_lng         : num [1:426887] -87.7 -87.7 -87.6 -87.6 -87.6 ...
#  $ end_lat           : num [1:426887] 42 42 41.9 41.9 41.9 ...
#  $ end_lng           : num [1:426887] -87.7 -87.7 -87.7 -87.6 -87.6 ...
#  $ member_casual     : chr [1:426887] "member" "member" "member" "member" ...
#  - attr(*, "spec")=
#   .. cols(
#   ..   ride_id = col_character(),
#   ..   rideable_type = col_character(),
#   ..   started_at = col_character(),
#   ..   ended_at = col_character(),
#   ..   start_station_name = col_character(),
#   ..   start_station_id = col_double(),
#   ..   end_station_name = col_character(),
#   ..   end_station_id = col_double(),
#   ..   start_lat = col_double(),
#   ..   start_lng = col_double(),
#   ..   end_lat = col_double(),
#   ..   end_lng = col_double(),
#   ..   member_casual = col_character()
#   .. )
#  - attr(*, "problems")=<externalptr>

# %% [markdown]
# Transform the two dataframes into a single dataframe.

# %%
all_trips <- bind_rows(q1_2019, q1_2020)

# %% [markdown]
# Remove columns for tripduration, lat, long, birthyear, and gender since these data were dropped in Divvy datasets starting 2020.

# %%
all_trips <- all_trips %>%
    select(-c(start_lat, start_lng, end_lat, end_lng, birthyear, gender,  "tripduration"))

# %% [markdown]
# ### Data Cleaning and Processing:
#
# Inspect the new dataframe.

# %%
colnames(all_trips)  
nrow(all_trips) 
dim(all_trips)  
head(all_trips) 
str(all_trips)
summary(all_trips)
# Out:
# [1] "ride_id"            "started_at"         "ended_at"
# [4] "rideable_type"      "start_station_id"   "start_station_name"
# [7] "end_station_id"     "end_station_name"   "member_casual"
# [1] 791956
# [1] 791956      9
#   ride_id  started_at         ended_at           rideable_type start_station_id
# 1 21742443 2019-01-01 0:04:37 2019-01-01 0:11:07 2167          199
# 2 21742444 2019-01-01 0:08:13 2019-01-01 0:15:34 4386           44
# 3 21742445 2019-01-01 0:13:23 2019-01-01 0:27:12 1524           15
# 4 21742446 2019-01-01 0:13:45 2019-01-01 0:43:28 252           123
# 5 21742447 2019-01-01 0:14:52 2019-01-01 0:20:56 1170          173
# 6 21742448 2019-01-01 0:15:33 2019-01-01 0:19:09 2437           98
#   start_station_name                  end_station_id
# 1 Wabash Ave & Grand Ave               84
# 2 State St & Randolph St              624
# 3 Racine Ave & 18th St                644
# 4 California Ave & Milwaukee Ave      176
# 5 Mies van der Rohe Way & Chicago Ave  35
# 6 LaSalle St & Washington St           49
#   end_station_name               member_casual
# 1 Milwaukee Ave & Grand Ave      Subscriber
# 2 Dearborn St & Van Buren St (*) Subscriber
# 3 Western Ave & Fillmore St (*)  Subscriber
# 4 Clark St & Elm St              Subscriber
# 5 Streeter Dr & Grand Ave        Subscriber
# 6 Dearborn St & Monroe St        Subscriber
# tibble [791,956 × 9] (S3: tbl_df/tbl/data.frame)
#  $ ride_id           : chr [1:791956] "21742443" "21742444" "21742445" "21742446" ...
#  $ started_at        : chr [1:791956] "2019-01-01 0:04:37" "2019-01-01 0:08:13" "2019-01-01 0:13:23" "2019-01-01 0:13:45" ...
#  $ ended_at          : chr [1:791956] "2019-01-01 0:11:07" "2019-01-01 0:15:34" "2019-01-01 0:27:12" "2019-01-01 0:43:28" ...
#  $ rideable_type     : chr [1:791956] "2167" "4386" "1524" "252" ...
#  $ start_station_id  : num [1:791956] 199 44 15 123 173 98 98 211 150 268 ...
#  $ start_station_name: chr [1:791956] "Wabash Ave & Grand Ave" "State St & Randolph St" "Racine Ave & 18th St" "California Ave & Milwaukee Ave" ...
#  $ end_station_id    : num [1:791956] 84 624 644 176 35 49 49 142 148 141 ...
#  $ end_station_name  : chr [1:791956] "Milwaukee Ave & Grand Ave" "Dearborn St & Van Buren St (*)" "Western Ave & Fillmore St (*)" "Clark St & Elm St" ...
#  $ member_casual     : chr [1:791956] "Subscriber" "Subscriber" "Subscriber" "Subscriber" ...
#    ride_id           started_at          ended_at         rideable_type
#  Length:791956      Length:791956      Length:791956      Length:791956
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#  start_station_id start_station_name end_station_id  end_station_name
#  Min.   :  2.0    Length:791956      Min.   :  2.0   Length:791956
#  1st Qu.: 77.0    Class :character   1st Qu.: 77.0   Class :character
#  Median :174.0    Mode  :character   Median :174.0   Mode  :character
#  Mean   :204.4                       Mean   :204.4
#  3rd Qu.:291.0                       3rd Qu.:291.0
#  Max.   :675.0                       Max.   :675.0
#                                      NA's   :1
#  member_casual
#  Length:791956
#  Class :character
#  Mode  :character

# %% [markdown]
# Recalling the description earlier on the data source, 2019 and 2020 Divvy datasets use different nomenclatures for the users. In the 2019 dataset, users are categorized as either *Subscriber* or *Customer*. In the 2020 dataset, users are categorized as either *member* or *casual*.

# %%
table(all_trips$member_casual)
# Out:
#     casual   Customer     member Subscriber
#      48480      23163     378407     341906

# %% [markdown]
# There are currently four categories under the *member_casual* column. Use a consistent nomenclature for member_casual by following the more recent dataframe (2020). Reassign *Subscriber* as *member* and *Customer* as *casual*.

# %%
all_trips <-  all_trips %>% 
  mutate(member_casual = recode(member_casual,
                                "Subscriber" = "member",
                                "Customer" = "casual"))

table(all_trips$member_casual)
# Out:
# casual member
#  71643 720313

# %% [markdown]
# Add information on month, day, year, day of the week for each record.

# %%
all_trips$date <- as.Date(all_trips$started_at)
all_trips$month <- format(as.Date(all_trips$date), "%m")
all_trips$day <- format(as.Date(all_trips$date), "%d")
all_trips$year <- format(as.Date(all_trips$date), "%Y")
all_trips$day_of_week <- format(as.Date(all_trips$date), "%A")

# %% [markdown]
# Add *ride_length* calculation for each record. Inspect the structure of the dataframe.

# %%
all_trips$ride_length <- difftime(all_trips$ended_at,all_trips$started_at)  # result is in seconds
str(all_trips)
# Out:
# tibble [791,956 × 15] (S3: tbl_df/tbl/data.frame)
#  $ ride_id           : chr [1:791956] "21742443" "21742444" "21742445" "21742446" ...
#  $ started_at        : chr [1:791956] "2019-01-01 0:04:37" "2019-01-01 0:08:13" "2019-01-01 0:13:23" "2019-01-01 0:13:45" ...
#  $ ended_at          : chr [1:791956] "2019-01-01 0:11:07" "2019-01-01 0:15:34" "2019-01-01 0:27:12" "2019-01-01 0:43:28" ...
#  $ rideable_type     : chr [1:791956] "2167" "4386" "1524" "252" ...
#  $ start_station_id  : num [1:791956] 199 44 15 123 173 98 98 211 150 268 ...
#  $ start_station_name: chr [1:791956] "Wabash Ave & Grand Ave" "State St & Randolph St" "Racine Ave & 18th St" "California Ave & Milwaukee Ave" ...
#  $ end_station_id    : num [1:791956] 84 624 644 176 35 49 49 142 148 141 ...
#  $ end_station_name  : chr [1:791956] "Milwaukee Ave & Grand Ave" "Dearborn St & Van Buren St (*)" "Western Ave & Fillmore St (*)" "Clark St & Elm St" ...
#  $ member_casual     : chr [1:791956] "member" "member" "member" "member" ...
#  $ date              : Date[1:791956], format: "2019-01-01" "2019-01-01" ...
#  $ month             : chr [1:791956] "01" "01" "01" "01" ...
#  $ day               : chr [1:791956] "01" "01" "01" "01" ...
#  $ year              : chr [1:791956] "2019" "2019" "2019" "2019" ...
#  $ day_of_week       : chr [1:791956] "Tuesday" "Tuesday" "Tuesday" "Tuesday" ...
#  $ ride_length       : 'difftime' num [1:791956] 390 441 829 1783 ...
#   ..- attr(*, "units")= chr "secs"

# %% [markdown]
# Convert *ride_length* to numeric datatype.

# %%
all_trips$ride_length <- as.numeric(as.character(all_trips$ride_length))
is.numeric(all_trips$ride_length)
# Out:
# [1] TRUE

# %% [markdown]
# When you inspect the *start_station_name* field, one value is *HQ QR*. These must be trips where the bikes were taken out of the docks and serviced by employees and not by customers. These records will be deleted from our data. Similarly, records with *end_station_name* field at *HQ QR* will also be deleted.
#
# Records with negative *ride_length* will also be deleted.

# %%
table(all_trips$start_station_name)
table(all_trips$end_station_name)
table(all_trips$ride_length)
# Out:
#                         2112 W Peterson Ave
#                                          87
#                               63rd St Beach
#                                         187
#                           900 W Harrison St
#                                        2046
#                  Aberdeen St & Jackson Blvd
#                                        2877
#                     Aberdeen St & Monroe St
#                                        2596
#                   Aberdeen St & Randolph St
#                                        2131
#                    Ada St & Washington Blvd
#                                        1720
#                           Adler Planetarium
#                                        1642
#                        Albany Ave & 26th St
#                                          36
#               Albany Ave & Bloomingdale Ave
#                                         818
#                   Albany Ave & Montrose Ave
#                                         140
#                Archer (Damen) Ave & 37th St
#                                          96
#            Archer (Damen) Ave & 37th St (*)
#                                          40
#                   Artesian Ave & Hubbard St
#                                        1637
#                       Ashland Ave & 13th St
#                                         548
#                       Ashland Ave & 21st St
#                                         145
#                       Ashland Ave & 50th St
#                                           7
#                       Ashland Ave & 63rd St
#                                          24
#                       Ashland Ave & 66th St
#                                           7
#                       Ashland Ave & 69th St
#                                          13
#                    Ashland Ave & Archer Ave
#                                         143
#                  Ashland Ave & Augusta Blvd
#                                        1099
#              Ashland Ave & Belle Plaine Ave
#                                         489
#                  Ashland Ave & Blackhawk St
#                                        1327
#                   Ashland Ave & Chicago Ave
#                                        1140
#                   Ashland Ave & Division St
#                                        4090
#                 Ashland Ave & Garfield Blvd
#                                          40
#                      Ashland Ave & Grace St
#                                         878
#                     Ashland Ave & Grand Ave
#                                         993
#                       Ashland Ave & Lake St
#                                         826
#                Ashland Ave & Lake St (Temp)
#                                         593
#                  Ashland Ave & McDowell Ave
#                                         171
#                   Ashland Ave & Pershing Rd
#                                          52
#                Ashland Ave & Wellington Ave
#                                         678
#                Ashland Ave & Wrightwood Ave
#                                        1045
#                   Austin Blvd & Chicago Ave
#                                          17
#                       Austin Blvd & Lake St
#                                          61
#                    Austin Blvd & Madison St
#                                          29
#                     Avers Ave & Belmont Ave
#                                         174
#               Avondale Ave & Irving Park Rd
#                                         323
#                       Bennett Ave & 79th St
#                                           8
#                      Benson Ave & Church St
#                                        1136
#                     Bernard St & Elston Ave
#                                         198
#                   Bissell St & Armitage Ave
#                                        2736
#             Blackstone Ave & Hyde Park Blvd
#                                         764
#                   Blue Island Ave & 18th St
#                                        1515
#                    Bosworth Ave & Howard St
#                                         150
#                        Broadway & Argyle St
#                                        1049
#                        Broadway & Barry Ave
#                                        3336
#                      Broadway & Belmont Ave
#                                        1773
#                       Broadway & Berwyn Ave
#                                        1222
#                     Broadway & Cornelia Ave
#                                        2249
#                    Broadway & Granville Ave
#                                         899
#                        Broadway & Ridge Ave
#                                         933
#                      Broadway & Sheridan Rd
#                                        1588
#                    Broadway & Thorndale Ave
#                                         774
#                     Broadway & Waveland Ave
#                                        2396
#                       Broadway & Wilson Ave
#                                        1569
#                         Buckingham Fountain
#                                         424
#                  Buckingham Fountain (Temp)
#                                         322
#                       Budlong Woods Library
#                                          99
# Burling St (Halsted) & Diversey Pkwy (Temp)
#                                        2019
#                              Burnham Harbor
#                                        1242
#                    California Ave & 21st St
#                                         177
#                    California Ave & 23rd Pl
#                                         239
#                    California Ave & 26th St
#                                          41
#                 California Ave & Altgeld St
#                                         488
#                   California Ave & Byron St
#                                         181
#                  California Ave & Cortez St
#                                         925
#                California Ave & Division St
#                                         365
#                California Ave & Fletcher St
#                                         294
#                 California Ave & Francis Pl
#                                         303
#          California Ave & Francis Pl (Temp)
#                                         277
#                    California Ave & Lake St
#                                         168
#              California Ave & Milwaukee Ave
#                                        1809
#               California Ave & Montrose Ave
#                                         365
#                  California Ave & North Ave
#                                         594
#                       Calumet Ave & 18th St
#                                        1409
#                       Calumet Ave & 21st St
#                                         443
#                       Calumet Ave & 33rd St
#                                         513
#                       Calumet Ave & 35th St
#                                         159
#                       Calumet Ave & 51st St
#                                         111
#                       Calumet Ave & 71st St
#                                          10
#                Campbell Ave & Fullerton Ave
#                                         442
#                 Campbell Ave & Montrose Ave
#                                         594
#                    Campbell Ave & North Ave
#                                         863
#                         Canal St & Adams St
#                                       14155
#                      Canal St & Harrison St
#                                         919
#                     Canal St & Jackson Blvd
#                                        2751
#                       Canal St & Madison St
#                                        8208
#                        Canal St & Monroe St
#                                        2355
#                    Canal St & Monroe St (*)
#                                        2137
#                        Canal St & Taylor St
#                                        1776
#                   Cannon Dr & Fullerton Ave
#                                         577
#                      Carpenter St & 63rd St
#                                           3
#                     Carpenter St & Huron St
#                                        1510
#                   Central Ave & Chicago Ave
#                                          35
#                   Central Ave & Harrison St
#                                           2
#                       Central Ave & Lake St
#                                          11
#                    Central Ave & Madison St
#                                          11
#                  Central Park Ave & 24th St
#                                          12
#         Central Park Ave & Bloomingdale Ave
#                                         361
#             Central Park Ave & Elbridge Ave
#                                         294
#                Central Park Ave & North Ave
#                                         201
#                Central Park Ave & Ogden Ave
#                                          33
#                 Central Park Blvd & 5th Ave
#                                          14
#                     Central St & Girard Ave
#                                         211
#                            Central St Metra
#                                         344
#                   Cherry Ave & Blackhawk St
#                                         187
#                   Chicago Ave & Dempster St
#                                         460
#                   Chicago Ave & Sheridan Rd
#                                         379
#                 Chicago Ave & Washington St
#                                         656
#               Christiana Ave & Lawrence Ave
#                                         281
#                    Cicero Ave & Flournoy St
#                                           6
#                        Cicero Ave & Lake St
#                                           6
#                      Cicero Ave & Quincy St
#                                          16
#             Cityfront Plaza Dr & Pioneer Ct
#                                        3445
#                   Claremont Ave & Hirsch St
#                                         908
#                  Clarendon Ave & Gordon Ter
#                                        1593
#                  Clarendon Ave & Junior Ter
#                                         808
#                  Clarendon Ave & Leland Ave
#                                         692
#                    Clark St & 9th St (AMLI)
#                                        1125
#                     Clark St & Armitage Ave
#                                        3305
#                       Clark St & Berwyn Ave
#                                        1394
#                    Clark St & Bryn Mawr Ave
#                                         929
#                      Clark St & Chicago Ave
#                                        2441
#                     Clark St & Columbia Ave
#                                         376
#                      Clark St & Drummond Pl
#                                        2157
#                           Clark St & Elm St
#                                        5059
#                      Clark St & Elmdale Ave
#                                         521
#                         Clark St & Grace St
#                                        1459
#                   Clark St & Ida B Wells Dr
#                                        3677
#                       Clark St & Jarvis Ave
#                                         207
#                          Clark St & Lake St
#                                        4223
#                       Clark St & Leland Ave
#                                         916
#                      Clark St & Lincoln Ave
#                                        2447
#                         Clark St & Lunt Ave
#                                         843
#                     Clark St & Montrose Ave
#                                         996
#                       Clark St & Newport St
#                                        1089
#                        Clark St & North Ave
#                                        1135
#                      Clark St & Randolph St
#                                        4435
#                      Clark St & Schiller St
#                                        2716
#                    Clark St & Schreiber Ave
#                                         339
#                        Clark St & Touhy Ave
#                                          91
#                   Clark St & Wellington Ave
#                                        2178
#                     Clark St & Winnemac Ave
#                                        1778
#                   Clark St & Wrightwood Ave
#                                        2814
#                  Clifton Ave & Armitage Ave
#                                        1550
#                        Clinton St & 18th St
#                                         613
#                   Clinton St & Jackson Blvd
#                                        2225
#               Clinton St & Jackson Blvd (*)
#                                        2720
#                        Clinton St & Lake St
#                                        6674
#                     Clinton St & Madison St
#                                       13362
#                        Clinton St & Polk St
#                                         169
#                    Clinton St & Polk St (*)
#                                         267
#                   Clinton St & Roosevelt Rd
#                                        1254
#                      Clinton St & Tilden St
#                                        2004
#                Clinton St & Washington Blvd
#                                       13640
#                  Clybourn Ave & Division St
#                                        1718
#                   Columbus Dr & Randolph St
#                                        9080
#                    Commercial Ave & 83rd St
#                                          14
#                   Conservatory Dr & Lake St
#                                          99
#                Cornell Ave & Hyde Park Blvd
#                                        1151
#                       Cornell Dr & Hayes Dr
#                                          11
#                 Cottage Grove Ave & 43rd St
#                                         127
#                 Cottage Grove Ave & 47th St
#                                         164
#                 Cottage Grove Ave & 51st St
#                                         208
#                 Cottage Grove Ave & 63rd St
#                                          85
#                 Cottage Grove Ave & 67th St
#                                          55
#                 Cottage Grove Ave & 71st St
#                                           6
#                 Cottage Grove Ave & 78th St
#                                          12
#                 Cottage Grove Ave & 83rd St
#                                          11
#            Cottage Grove Ave & Oakwood Blvd
#                                          96
#                          Daley Center Plaza
#                                        6251
#                         Damen Ave & 51st St
#                                          10
#                         Damen Ave & 59th St
#                                          12
#                   Damen Ave & Charleston St
#                                         801
#                     Damen Ave & Chicago Ave
#                                        1870
#                    Damen Ave & Clybourn Ave
#                                         782
#                     Damen Ave & Cortland St
#                                        1765
#                      Damen Ave & Coulter St
#                                          59
#                    Damen Ave & Cullerton St
#                                         343
#                     Damen Ave & Division St
#                                        1909
#                      Damen Ave & Foster Ave
#                                         806
#                       Damen Ave & Grand Ave
#                                        1037
#                      Damen Ave & Leland Ave
#                                        1535
#                      Damen Ave & Madison St
#                                         491
#                     Damen Ave & Melrose Ave
#                                         426
#                     Damen Ave & Pershing Rd
#                                          12
#                      Damen Ave & Pierce Ave
#                                        4042
#                   Damen Ave & Sunnyside Ave
#                                         443
#        Damen Ave & Thomas St (Augusta Blvd)
#                                        1293
#            Damen Ave & Walnut (Lake) St (*)
#                                         272
#                  Damen Ave & Wellington Ave
#                                         565
#                       Dayton St & North Ave
#                                        1896
#                 Dearborn Pkwy & Delaware Pl
#                                        3376
#                      Dearborn St & Adams St
#                                        3395
#                       Dearborn St & Erie St
#                                        5618
#                     Dearborn St & Monroe St
#                                        6332
#                  Dearborn St & Van Buren St
#                                         861
#              Dearborn St & Van Buren St (*)
#                                         763
#                    Delano Ct & Roosevelt Rd
#                                        1334
#                Desplaines St & Jackson Blvd
#                                        3931
#                   Desplaines St & Kinzie St
#                                        5521
#                 Desplaines St & Randolph St
#                                        2676
#                 DIVVY Map Frame B/C Station
#                                           7
#                       Dodge Ave & Church St
#                                         161
#                      Dodge Ave & Mulford St
#                                         103
#                    Dorchester Ave & 49th St
#                                         183
#                    Dorchester Ave & 63rd St
#                                          52
#                      Drake Ave & Addison St
#                                         468
#                   Drake Ave & Fullerton Ave
#                                         433
#                    Drake Ave & Montrose Ave
#                                         226
#                              Dusable Harbor
#                                        1352
#                              DuSable Museum
#                                          84
#                   Eastlake Ter & Rogers Ave
#                                         578
#                      Eberhart Ave & 61st St
#                                          40
#                                Eckhart Park
#                                        1327
#                 Eggleston Ave & 69th St (*)
#                                          13
#              Elizabeth (May) St & Fulton St
#                                         749
#                      Elizabeth St & 47th St
#                                          16
#                      Elizabeth St & 59th St
#                                           4
#                         Ellis Ave & 53rd St
#                                        1441
#                         Ellis Ave & 55th St
#                                        2719
#                         Ellis Ave & 58th St
#                                        1745
#                         Ellis Ave & 60th St
#                                        2577
#                         Ellis Ave & 83rd St
#                                           3
#                     Elmwood Ave & Austin St
#                                         224
#                   Elston Ave & Wabansia Ave
#                                         566
#                       Emerald Ave & 28th St
#                                         556
#                       Emerald Ave & 31st St
#                                         680
#                         Evans Ave & 75th St
#                                          15
#                       Evanston Civic Center
#                                         106
#                      Exchange Ave & 79th St
#                                          10
#                    Fairbanks Ct & Grand Ave
#                                        4145
#                  Fairbanks St & Superior St
#                                         986
#              Fairbanks St & Superior St (*)
#                                         994
#                Fairfield Ave & Roosevelt Rd
#                                          35
#                        Federal St & Polk St
#                                        3021
#                 Field Blvd & South Water St
#                                        1795
#                                Field Museum
#                                        1139
#               Financial Pl & Ida B Wells Dr
#                                        1264
#        Financial Pl & Ida B Wells Dr (Temp)
#                                        1197
#                  Fort Dearborn Dr & 31st St
#                                         578
#                  Francisco Ave & Foster Ave
#                                         288
#               Franklin St & Adams St (Temp)
#                                        1458
#                   Franklin St & Chicago Ave
#                                        3549
#                   Franklin St & Illinois St
#                                        1485
#                  Franklin St & Jackson Blvd
#                                        5495
#                       Franklin St & Lake St
#                                        4460
#                     Franklin St & Monroe St
#                                        7227
#                     Franklin St & Quincy St
#                                        1953
#                    Glenwood Ave & Morse Ave
#                                         669
#                    Glenwood Ave & Touhy Ave
#                                         227
#                       Green St & Madison St
#                                        3507
#                      Green St & Randolph St
#                                        2607
#               Greenview Ave & Diversey Pkwy
#                                         757
#               Greenview Ave & Fullerton Ave
#                                        1255
#                  Greenview Ave & Jarvis Ave
#                                         535
#                     Greenwood Ave & 47th St
#                                         359
#                     Greenwood Ave & 79th St
#                                          10
#                        Halsted St & 18th St
#                                         484
#                        Halsted St & 21st St
#                                         284
#                        Halsted St & 35th St
#                                         119
#                    Halsted St & 35th St (*)
#                                          56
#                        Halsted St & 37th St
#                                         110
#                        Halsted St & 47th Pl
#                                          65
#                        Halsted St & 51st St
#                                           6
#                        Halsted St & 56th St
#                                           4
#                        Halsted St & 59th St
#                                           2
#                        Halsted St & 63rd St
#                                          36
#                        Halsted St & 69th St
#                                           3
#                     Halsted St & Archer Ave
#                                         493
#                   Halsted St & Clybourn Ave
#                                        1897
#               Halsted St & Clybourn Ave (*)
#                                        1294
#                    Halsted St & Dickens Ave
#                                        1803
#                     Halsted St & Maxwell St
#                                        1199
#                Halsted St & North Branch St
#                                         444
#                        Halsted St & Polk St
#                                        2058
#                   Halsted St & Roosevelt Rd
#                                        1599
#                      Halsted St & Roscoe St
#                                        2027
#                      Halsted St & Willow St
#                                        1276
#                 Halsted St & Wrightwood Ave
#                                        1840
#                        Harper Ave & 59th St
#                                         896
#                     Hermitage Ave & Polk St
#                                        1247
#                     Honore St & Division St
#                                        1690
#                         Hoyne Ave & 47th St
#                                          48
#                    Hoyne Ave & Balmoral Ave
#                                         318
#                                       HQ QR
#                                        3767
#      HUBBARD ST BIKE CHECKING (LBS-WH-TEST)
#                                           4
#                Humboldt Blvd & Armitage Ave
#                                         763
#                       Indiana Ave & 26th St
#                                         452
#                       Indiana Ave & 31st St
#                                         572
#                       Indiana Ave & 40th St
#                                          57
#                  Indiana Ave & Roosevelt Rd
#                                        3993
#                    Jefferson St & Monroe St
#                                        2321
#                      Jeffery Blvd & 67th St
#                                          28
#                      Jeffery Blvd & 71st St
#                                          56
#                      Jeffery Blvd & 76th St
#                                           5
#                     Karlov Ave & Madison St
#                                          20
#                        Kedzie Ave & 21st St
#                                         105
#                        Kedzie Ave & 24th St
#                                          16
#                  Kedzie Ave & Bryn Mawr Ave
#                                          69
#                    Kedzie Ave & Chicago Ave
#                                         154
#                     Kedzie Ave & Foster Ave
#                                         213
#                    Kedzie Ave & Harrison St
#                                          16
#                        Kedzie Ave & Lake St
#                                         227
#                     Kedzie Ave & Leland Ave
#                                         244
#                  Kedzie Ave & Milwaukee Ave
#                                        1681
#                      Kedzie Ave & Palmer Ct
#                                         941
#                   Kedzie Ave & Roosevelt Rd
#                                          19
#                     Kenton Ave & Madison St
#                                           8
#                Keystone Ave & Fullerton Ave
#                                         112
#                 Keystone Ave & Montrose Ave
#                                         111
#               Kilbourn Ave & Irving Park Rd
#                                         131
#                Kilbourn Ave & Milwaukee Ave
#                                         117
#                  Kildare Ave & Montrose Ave
#                                          63
#                   Kimball Ave & Belmont Ave
#                                         271
#                       Kimbark Ave & 53rd St
#                                        2347
#                      Kingsbury St & Erie St
#                                        4876
#                    Kingsbury St & Kinzie St
#                                        9021
#                     Knox Ave & Montrose Ave
#                                         147
#                             Kosciuszko Park
#                                         468
#                      Kostner Ave & Adams St
#                                          13
#                       Kostner Ave & Lake St
#                                           4
#                    Laflin St & Cullerton St
#                                         279
#                     Lake Park Ave & 35th St
#                                         414
#                     Lake Park Ave & 47th St
#                                         261
#                     Lake Park Ave & 53rd St
#                                         771
#                     Lake Park Ave & 56th St
#                                        1570
#                 Lake Shore Dr & Belmont Ave
#                                        1661
#               Lake Shore Dr & Diversey Pkwy
#                                        1326
#                   Lake Shore Dr & Monroe St
#                                        3811
#                  Lake Shore Dr & North Blvd
#                                        1956
#                     Lake Shore Dr & Ohio St
#                                        1883
#              Lake Shore Dr & Wellington Ave
#                                        1594
#             Lakefront Trail & Bryn Mawr Ave
#                                         899
#                Lakefront Trail & Wilson Ave
#                                         621
#               Lakeview Ave & Fullerton Pkwy
#                                        2101
#                    Laramie Ave & Gladys Ave
#                                          10
#                     Laramie Ave & Kinzie St
#                                           3
#                    Laramie Ave & Madison St
#                                          12
#                  Larrabee St & Armitage Ave
#                                        1347
#                   Larrabee St & Division St
#                                        2324
#                  Larrabee St & Kingsbury St
#                                        6708
#                  Larrabee St & Menomonee St
#                                        1038
#                     Larrabee St & North Ave
#                                         736
#                        Larrabee St & Oak St
#                                        2235
#                   Larrabee St & Webster Ave
#                                        2306
#                       LaSalle Dr & Huron St
#                                        1260
#                   LaSalle Dr & Huron St (*)
#                                         852
#                       LaSalle St & Adams St
#                                        2115
#                    LaSalle St & Illinois St
#                                        3954
#                   LaSalle St & Jackson Blvd
#                                        6426
#                  LaSalle St & Washington St
#                                        3484
#                   Latrobe Ave & Chicago Ave
#                                           3
#                     Leavitt St & Addison St
#                                         242
#                     Leavitt St & Archer Ave
#                                         118
#                   Leavitt St & Armitage Ave
#                                         777
#                Leavitt St & Belmont Ave (*)
#                                         346
#                    Leavitt St & Chicago Ave
#                                         746
#                Leavitt St & Division St (*)
#                                         497
#                   Leavitt St & Lawrence Ave
#                                         534
#                      Leavitt St & North Ave
#                                        1017
#                    Lincoln Ave & Addison St
#                                         433
#              Lincoln Ave & Belle Plaine Ave
#                                         778
#                   Lincoln Ave & Belmont Ave
#                                        1362
#                 Lincoln Ave & Diversey Pkwy
#                                        1551
#                 Lincoln Ave & Fullerton Ave
#                                        2524
#                     Lincoln Ave & Roscoe St
#                                        1663
#                 Lincoln Ave & Sunnyside Ave
#                                         928
#                  Lincoln Ave & Waveland Ave
#                                         911
#                     Lincoln Ave & Winona St
#                                         310
#                   Lincoln Park Conservatory
#                                         633
#                 Lincolnwood Dr & Central St
#                                         197
#                     Logan Blvd & Elston Ave
#                                         763
#                      Loomis St & Archer Ave
#                                         294
#                    Loomis St & Jackson Blvd
#                                        1123
#                    Loomis St & Lexington St
#                                        2880
#                   Loomis St & Taylor St (*)
#                                         443
#                           Malcolm X College
#                                         262
#                      Manor Ave & Leland Ave
#                                         229
#                Maplewood Ave & Peterson Ave
#                                          26
#                      Marine Dr & Ainslie St
#                                         578
#                    Marshfield Ave & 44th St
#                                          14
#                    Marshfield Ave & 59th St
#                                           6
#                Marshfield Ave & Cortland St
#                                        3638
#                            May St & 69th St
#                                          12
#                       May St & Cullerton St
#                                         401
#                          May St & Taylor St
#                                        1452
#                        McClurg Ct & Erie St
#                                        3746
#                    McClurg Ct & Illinois St
#                                        3751
#                             McCormick Place
#                                         655
#                      Michigan Ave & 14th St
#                                        2215
#                      Michigan Ave & 18th St
#                                        2080
#                      Michigan Ave & 71st St
#                                           2
#                       Michigan Ave & 8th St
#                                        1661
#               Michigan Ave & Ida B Wells Dr
#                                        1487
#                 Michigan Ave & Jackson Blvd
#                                        2559
#                      Michigan Ave & Lake St
#                                        6113
#                   Michigan Ave & Madison St
#                                        2499
#                       Michigan Ave & Oak St
#                                        2813
#                   Michigan Ave & Pearson St
#                                        1511
#                Michigan Ave & Washington St
#                                        7525
#         Mies van der Rohe Way & Chestnut St
#                                        2429
#         Mies van der Rohe Way & Chicago Ave
#                                        2809
#                       Millard Ave & 26th St
#                                          14
#                             Millennium Park
#                                        3796
#                  Milwaukee Ave & Cuyler Ave
#                                         102
#                   Milwaukee Ave & Grand Ave
#                                        3566
#                 Milwaukee Ave & Rockwell St
#                                         646
#                Milwaukee Ave & Wabansia Ave
#                                        2026
#                         MLK Jr Dr & 29th St
#                                        1006
#                         MLK Jr Dr & 47th St
#                                          44
#                         MLK Jr Dr & 56th St
#                                          16
#                     MLK Jr Dr & 56th St (*)
#                                          25
#                         MLK Jr Dr & 63rd St
#                                          33
#                         MLK Jr Dr & 83rd St
#                                          21
#                     MLK Jr Dr & Pershing Rd
#                                         198
#             Monticello Ave & Irving Park Rd
#                                         287
#                             Montrose Harbor
#                                         824
#                        Morgan Ave & 14th Pl
#                                        1040
#                         Morgan St & 18th St
#                                        1057
#                         Morgan St & 31st St
#                                         338
#                         Morgan St & Lake St
#                                        4891
#                     Morgan St & Pershing Rd
#                                          20
#                         Morgan St & Polk St
#                                        3224
#                               MTL-ECO5.1-01
#                                           8
#              Museum of Science and Industry
#                                         358
#                    Noble St & Milwaukee Ave
#                                        1582
#                     Normal Ave & Archer Ave
#                                         294
#                 Oakley Ave & Irving Park Rd
#                                         414
#                      Oakley Ave & Touhy Ave
#                                          92
#                     Ogden Ave & Chicago Ave
#                                        2075
#                   Ogden Ave & Congress Pkwy
#                                         371
#                        Ogden Ave & Race Ave
#                                        1678
#                    Ogden Ave & Roosevelt Rd
#                                         226
#        Orleans St & Chestnut St (NEXT Apts)
#                                        1742
#                         Orleans St & Elm St
#                                         501
#                     Orleans St & Elm St (*)
#                                         561
#                     Orleans St & Hubbard St
#                                        1009
#                 Orleans St & Hubbard St (*)
#                                        1072
#         Orleans St & Merchandise Mart Plaza
#                                        5048
#                     Paulina Ave & North Ave
#                                        1233
#                        Paulina St & 18th St
#                                         877
#                    Paulina St & Flournoy St
#                                        1102
#                      Paulina St & Howard St
#                                         508
#                   Paulina St & Montrose Ave
#                                         509
#                    Peoria St & Jackson Blvd
#                                        3342
#                         Perry Ave & 69th St
#                                          17
#                      Phillips Ave & 79th St
#                                          11
#                      Phillips Ave & 83rd St
#                                           5
#             Pine Grove Ave & Irving Park Rd
#                                        1983
#               Pine Grove Ave & Waveland Ave
#                                        2189
#                       Prairie Ave & 43rd St
#                                         140
#                 Prairie Ave & Garfield Blvd
#                                         300
#                     Princeton Ave & 47th St
#                                         108
#               Princeton Ave & Garfield Blvd
#                                         118
#                  Pulaski Rd & Congress Pkwy
#                                          34
#                 Pulaski Rd & Eddy St (Temp)
#                                         150
#                        Pulaski Rd & Lake St
#                                          16
#             Racine Ave (May St) & Fulton St
#                                         842
#                        Racine Ave & 13th St
#                                         326
#                        Racine Ave & 15th St
#                                         444
#                        Racine Ave & 18th St
#                                        1117
#                        Racine Ave & 35th St
#                                         108
#                        Racine Ave & 61st St
#                                           3
#                    Racine Ave & Belmont Ave
#                                        1237
#                  Racine Ave & Congress Pkwy
#                                        1468
#                  Racine Ave & Fullerton Ave
#                                        1750
#                  Racine Ave & Garfield Blvd
#                                          37
#                    Racine Ave & Randolph St
#                                        1240
#            Racine Ave & Washington Blvd (*)
#                                        1078
#                 Racine Ave & Wrightwood Ave
#                                        1214
#                               Rainbow Beach
#                                          15
#                Ravenswood Ave & Berteau Ave
#                                         628
#             Ravenswood Ave & Irving Park Rd
#                                         894
#               Ravenswood Ave & Lawrence Ave
#                                        4094
#                        Rhodes Ave & 32nd St
#                                         222
#                  Richmond St & Diversey Ave
#                                         423
#                      Ridge Blvd & Howard St
#                                         141
#                      Ridge Blvd & Touhy Ave
#                                         157
#                       Ritchie Ct & Banks St
#                                        1657
#                  Rockwell St & Eastwood Ave
#                                         467
#                          Rush St & Cedar St
#                                        2103
#                        Rush St & Hubbard St
#                                        3145
#                       Rush St & Superior St
#                                        3127
#             Sacramento Blvd & Franklin Blvd
#                                         101
#               Sangamon St & Washington Blvd
#                                         939
#           Sangamon St & Washington Blvd (*)
#                                        1104
#                 Sawyer Ave & Irving Park Rd
#                                         115
#                      Sedgwick St & Huron St
#                                        3485
#                     Sedgwick St & North Ave
#                                        2666
#                   Sedgwick St & Schiller St
#                                         681
#                   Sedgwick St & Webster Ave
#                                        2419
#                  Seeley Ave & Garfield Blvd
#                                           4
#                      Seeley Ave & Roscoe St
#                                         756
#                              Shedd Aquarium
#                                        2899
#               Sheffield Ave & Fullerton Ave
#                                        4139
#                Sheffield Ave & Kingsbury St
#                                        2221
#                Sheffield Ave & Waveland Ave
#                                        1773
#                 Sheffield Ave & Webster Ave
#                                        2154
#              Sheffield Ave & Wellington Ave
#                                        2264
#                   Sheffield Ave & Willow St
#                                        1985
#              Sheffield Ave & Wrightwood Ave
#                                        1385
#                     Sheridan Rd & Buena Ave
#                                         943
#                  Sheridan Rd & Columbia Ave
#                                         433
#                 Sheridan Rd & Greenleaf Ave
#                                         294
#                Sheridan Rd & Irving Park Rd
#                                        3159
#                  Sheridan Rd & Lawrence Ave
#                                         654
#                    Sheridan Rd & Loyola Ave
#                                         637
#                  Sheridan Rd & Montrose Ave
#                                        1406
#                 Sheridan Rd & Noyes St (NU)
#                                         809
#                       Shields Ave & 28th Pl
#                                         184
#                       Shields Ave & 31st St
#                                         362
#                       Shields Ave & 43rd St
#                                          40
#                          Shore Dr & 55th St
#                                        1342
#                              Smith Park (*)
#                                         152
#                 South Chicago Ave & 83rd St
#                                           6
#              South Chicago Ave & Elliot Ave
#                                           1
#                    South Shore Dr & 67th St
#                                         131
#                    South Shore Dr & 71st St
#                                         123
#                    South Shore Dr & 74th St
#                                          37
#                 Southport Ave & Belmont Ave
#                                         918
#                    Southport Ave & Clark St
#                                         731
#                Southport Ave & Clybourn Ave
#                                        1638
#              Southport Ave & Irving Park Rd
#                                        1183
#                   Southport Ave & Roscoe St
#                                        2520
#                Southport Ave & Waveland Ave
#                                        2378
#              Southport Ave & Wellington Ave
#                                        2113
#              Southport Ave & Wrightwood Ave
#                                        1327
#                Spaulding Ave & Armitage Ave
#                                         805
#                 Spaulding Ave & Division St
#                                         231
# ...
#    45403    45549    45727    45983    46052    46390    46527    46710
#        1        1        1        1        1        1        1        1
#    46758    47494    47565    47638    47649    47679    47692    47734
#        1        1        1        1        1        1        1        1
#    47884    48031    48039    48110    48198    48352    48362    48416
#        1        1        1        1        1        1        1        1
#    48492    48954    48997    49049    49234    49300    49360    49380
#        1        1        1        1        1        1        1        1
#    49435    49574    49598    49643    49651    49701    49761    49869
#        1        1        1        1        1        1        1        1
#    50226    50273    50297    50361    50404    50419    50535    50644
#        1        1        1        1        1        1        1        1
#    50652    50685    50730    50732    50761    50862    50890    50956
#        1        1        1        1        1        1        1        1
#    50966    50970    51324    51618    51629    51711    51760    52083
#        1        1        1        1        1        1        1        1
#    52178    52190    52507    52539    52676    52749    52785    52841
#        1        1        1        1        1        1        1        1
#    52892    52929    52962    53000    53011    53035    53037    53098
#        1        1        1        1        1        1        1        1
#    53129    53151    53221    53326    53400    53538    53591    53663
#        1        1        1        1        1        1        1        1
#    53674    53729    53841    53859    53870    53918    54040    54146
#        1        1        1        1        1        1        1        1
#    54313    54471    54498    54681    54712    54766    54858    55079
#        1        1        1        1        1        1        1        1
#    55104    55140    55146    55195    55346    55390    55432    55441
#        1        1        1        1        1        1        1        1
#    55519    55564    55598    55836    55866    56047    56211    56337
#        1        1        1        1        1        1        1        1
#    56351    56369    56401    56416    56422    56637    56663    56667
#        1        1        1        1        1        1        1        1
#    56849    56862    56920    57022    57090    57231    57232    57269
#        1        1        1        1        1        1        1        1
#    57575    57718    57925    57948    58048    58159    58316    58365
#        1        1        1        1        1        1        1        1
#    58492    58560    58625    58819    58831    58844    59178    59321
#        1        1        1        1        1        1        1        1
#    59638    59688    59846    59926    59929    59949    59989    60017
#        1        1        1        2        1        1        1        1
#    60215    60363    60366    60371    60434    60447    60732    60817
#        1        1        1        1        1        1        1        1
#    60909    61081    61240    61292    61297    61379    61492    61661
#        1        1        1        1        1        1        1        1
#    61750    61768    61835    62113    62171    62210    62250    62308
#        1        1        1        1        1        1        1        1
#    62395    62414    62456    62514    62540    62783    62784    62882
#        1        1        1        1        1        1        1        1
#    62940    62950    63143    63150    63286    63467    63594    63718
#        1        1        1        1        1        1        1        1
#    63732    63956    64132    64133    64316    64483    64588    64638
#        1        1        1        1        1        1        1        1
#    64646    64888    64891    65035    65141    65262    65296    65418
#        1        1        1        1        1        1        1        1
#    65651    65806    65826    65934    65994    66089    66221    66225
#        1        1        1        1        1        1        1        1
#    66259    66344    66376    66622    66655    66739    66913    66922
#        1        1        1        1        1        1        1        1
#    66929    66982    67183    67402    67429    67556    67770    68023
#        1        1        1        1        1        1        1        1
#    68032    68089    68145    68302    68348    68415    68665    68679
#        1        1        1        1        1        1        1        1
#    68699    68719    68791    68828    68910    68986    69116    69154
#        1        1        1        1        1        1        1        1
#    69362    69403    69599    69639    69687    69730    69791    70064
#        1        1        1        1        1        1        1        1
#    70132    70307    70382    70459    70551    70552    70593    70782
#        1        1        1        1        1        1        1        1
#    70842    70945    71012    71040    71094    71110    71118    71170
#        1        1        1        1        1        1        1        1
#    71195    71351    71380    71520    71528    71540    71592    71645
#        1        1        1        1        1        1        1        1
#    71768    71903    72024    72085    72278    72404    72609    72758
#        1        1        1        1        1        1        1        2
#    72824    73238    73528    73748    73797    73834    73894    74330
#        1        1        1        1        1        1        1        1
#    74358    74363    74442    74565    74852    74862    74983    75174
#        1        1        1        1        1        1        1        1
#    75238    75270    75557    75675    76100    76232    76340    76350
#        1        1        1        1        1        1        1        1
#    76766    76971    77001    77175    77185    77665    77842    77975
#        1        1        1        1        1        1        1        1
#    78008    78058    78059    78113    78160    78291    78300    78599
#        1        1        1        1        1        1        1        1
#    78618    78730    78739    78849    79027    79042    79055    79211
#        1        1        1        1        1        1        1        1
#    79253    79271    79326    79397    79525    80031    80197    80592
#        1        1        1        1        1        1        1        1
#    80851    80884    80946    81029    81058    81071    81335    81465
#        1        1        1        1        1        1        1        1
#    81483    81521    81679    81680    81709    81860    81973    82083
#        1        1        1        1        1        1        2        1
#    82211    82613    82831    82853    83133    83233    83253    83269
#        1        1        1        1        1        1        1        1
#    83376    83485    83612    83683    84002    84589    84721    85072
#        1        1        1        1        2        1        1        1
#    85302    85554    85684    85928    85984    85990    86155    86448
#        1        1        1        1        1        1        1        1
#    86554    86842    86962    86990    87044    87140    87198    87211
#        1        1        1        1        1        1        1        1
#    87258    87346    87387    87494    87576    87660    87678    87775
#        1        1        1        1        1        1        1        1
#    87797    87891    87977    88026    88097    88147    88177    88320
#        1        1        1        1        1        1        1        1
#    88529    88573    88924    88937    89074    89168    89180    89237
#        1        1        1        1        1        1        1        1
#    89280    89307    89458    89649    89695    89729    89760    89936
#        1        1        1        1        1        1        1        1
#    90045    90392    90546    90575    90629    91050    91098    91180
#        1        1        1        1        1        1        1        1
#    91537    92046    92133    92166    92235    92236    92454    92528
#        1        1        1        1        1        1        1        1
#    92567    92586    92628    92695    92768    92792    93601    93648
#        1        1        1        1        1        1        1        1
#    93724    93876    93958    93965    94402    94566    94613    94747
#        1        1        1        1        1        1        1        1
#    95109    95430    95511    95569    95691    95950    96448    96453
#        1        1        1        1        1        1        1        1
#    96750    96772    97496    98229    98329    98348    98628    98823
#        1        1        1        1        1        1        1        1
#    99008    99014    99058    99124    99346    99524    99679   100093
#        1        1        1        1        1        1        1        1
#   100341   100412   100592   100779   100850   101046   101100   101227
#        1        1        1        1        1        1        1        1
#   101452   101518   101649   102100   102126   102900   102959   102986
#        1        1        1        1        1        1        1        1
#   103011   103200   103241   104135   104825   105025   105173   105210
#        1        1        1        1        1        1        1        1
#   106152   107435   107605   107653   108691   108777   109556   109689
#        1        1        1        1        1        1        1        1
#   111810   112014   112466   114676   115431   116728   122889   124487
#        1        1        1        1        1        1        1        1
#   125638   125705   127846   129033   129955   131207   131354   132150
#        1        1        1        1        1        1        1        1
#   133155   133845   134237   134288   134867   137123   137342   137795
#        1        1        1        1        1        1        1        1
#   138512   140244   140534   140542   140801   141362   143379   144577
#        1        1        1        1        1        1        1        1
#   146189   146302   147407   147465   147795   148567   149069   149088
#        1        1        1        1        1        1        1        1
#   149350   149354   149600   149634   149728   149812   150405   150722
#        1        1        1        1        1        1        1        1
#   150836   151382   151852   152096   152199   152371   152988   153485
#        1        1        1        1        1        1        1        1
#   154026   154275   154301   155185   155519   155559   155949   156606
#        1        1        1        1        1        1        1        1
#   156693   156921   157204   157486   157709   158095   158510   158914
#        1        1        1        1        1        1        1        1
#   159367   159462   160072   160586   160680   161043   162556   162786
#        1        1        1        1        1        1        1        1
#   162957   163343   163583   164414   166260   166820   167352   167805
#        1        1        1        1        1        1        1        1
#   168552   168799   168913   171017   171557   171675   171732   171845
#        1        1        1        1        1        1        1        1
#   172302   172454   172467   172477   172609   173265   174070   174293
#        1        1        1        1        1        1        1        1
#   175616   176342   176495   176708   176790   177475   178948   178966
#        1        1        1        1        1        1        1        1
#   179722   179746   179833   180042   181005   181130   183370   183414
#        1        1        1        1        1        1        1        1
#   183673   184772   185730   186073   187504   190254   194455   195147
#        1        1        1        1        1        1        1        1
#   196331   197061   199533   200317   200359   206622   209172   209229
#        1        1        1        1        1        1        1        1
#   209356   212609   214044   215493   217669   218308   221656   221719
#        1        1        1        1        1        1        1        1
#   222608   224614   225695   231879   232674   234209   236063   237997
#        1        1        1        1        1        1        1        1
#   239604   241708   242152   242662   246665   249014   249274   249781
#        1        1        1        1        1        1        1        1
#   250303   252195   253646   254049   254112   255460   257016   257358
#        1        1        1        1        1        1        1        1
#   259630   261751   262635   262823   264821   270658   273059   273496
#        1        1        1        1        1        1        1        1
#   273627   274780   278419   279943   282910   286449   288983   289709
#        1        1        1        1        1        1        1        1
#   291205   305605   306491   312561   313510   315300   315569   315974
#        1        1        1        1        1        1        1        1
#   317387   319919   323032   323266   323730   326970   329900   330173
#        1        1        1        1        1        1        1        1
#   330325   330716   330888   333033   335251   340203   341699   346393
#        1        1        1        1        1        1        1        1
#   347120   350245   351202   354469   355719   357387   360767   378974
#        1        1        1        1        1        1        1        1
#   389591   395770   400492   401003   403370   418352   419112   420535
#        1        1        1        1        1        1        1        1
#   420540   424343   424680   428594   429263   431874   433665   437515
#        1        1        1        1        1        1        1        1
#   439214   440069   451172   455202   455299   459127   460498   466867
#        1        1        1        1        1        1        1        1
#   477724   479496   484192   489082   489382   493353   515092   515519
#        1        1        1        1        1        1        1        1
#   518435   518702   521489   531183   564837   570499   578430   586669
#        1        1        1        1        1        1        1        1
#   601034   608557   610041   610185   611210   619929   625452   647009
#        1        1        1        1        1        1        1        1
#   647770   665816   666650   673271   700776   706404   735375   751616
#        1        1        1        1        1        1        1        1
#   757948   759365   759546   769022   777405   782294   783705   809697
#        1        1        1        1        1        1        1        1
#   811872   823086   826160   835799   847568   857052   882759   904637
#        1        1        1        1        1        1        1        1
#   911700   928986   940780   947276   959086   988255  1006874  1044947
#        1        1        1        1        1        1        1        1
#  1120901  1195678  1210860  1231182  1273864  1280807  1368311  1384483
#        1        1        1        1        1        1        1        1
#  1408473  1546032  1609620  1646142  1664154  1764842  1803517  1887866
#        1        1        1        1        1        1        1        1
#  1952536  1971032  2094081  2171014  2200317  2241583  2241642  2253331
#        1        1        1        1        1        1        1        1
#  2265055  2324187  2358946  2363255  2417075  2505738  2577374  2591131
#        1        1        1        1        1        1        1        1
#  2592879  2653452  3099272  3184339  3390506  3406963  3427056  3435010
#        1        1        1        1        1        1        1        1
#  3711293  3821916  3930450  3939702  4170291  4482201  4753051  4863068
#        1        1        1        1        1        1        1        1
#  5386959  5399506  5627611  5649778  6096428  7039405  8636205  9387024
#        1        1        1        1        1        1        1        1
# 10632022
#        1

# %% [markdown]
# Delete the records with bad data: *start_station_name* and *end_station_name* at *HQ QR* and negative *ride_length*.

# %%
all_trips_cleaned <- all_trips[!(all_trips$start_station_name == "HQ QR" | all_trips$ride_length<0),]

# %% [markdown]
# Summarize analysis metrics on *ride_length*.

# %%
summary(all_trips_cleaned$ride_length)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#        1      331      539     1189      912 10632022

# %% [markdown]
# Compare metrics between member and casual cyclists.

# %%
aggregate(all_trips_cleaned$ride_length ~ all_trips_cleaned$member_casual, FUN = mean)
aggregate(all_trips_cleaned$ride_length ~ all_trips_cleaned$member_casual, FUN = median)
aggregate(all_trips_cleaned$ride_length ~ all_trips_cleaned$member_casual, FUN = max)
aggregate(all_trips_cleaned$ride_length ~ all_trips_cleaned$member_casual, FUN = min)
# Out:
#   all_trips_cleaned$member_casual all_trips_cleaned$ride_length
# 1 casual                          5372.7839
# 2 member                           795.2523
#   all_trips_cleaned$member_casual all_trips_cleaned$ride_length
# 1 casual                          1393
# 2 member                           508
#   all_trips_cleaned$member_casual all_trips_cleaned$ride_length
# 1 casual                          10632022
# 2 member                           6096428
#   all_trips_cleaned$member_casual all_trips_cleaned$ride_length
# 1 casual                          2
# 2 member                          1

# %% [markdown]
# See the average *ride_length* each day for members vs casual cyclists.

# %%
all_trips_cleaned$day_of_week <- ordered(all_trips_cleaned$day_of_week, levels=c("Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"))
aggregate(all_trips_cleaned$ride_length ~ all_trips_cleaned$member_casual + all_trips_cleaned$day_of_week, FUN = mean)
# Out:
#    all_trips_cleaned$member_casual all_trips_cleaned$day_of_week
# 1  casual                          Sunday
# 2  member                          Sunday
# 3  casual                          Monday
# 4  member                          Monday
# 5  casual                          Tuesday
# 6  member                          Tuesday
# 7  casual                          Wednesday
# 8  member                          Wednesday
# 9  casual                          Thursday
# 10 member                          Thursday
# 11 casual                          Friday
# 12 member                          Friday
# 13 casual                          Saturday
# 14 member                          Saturday
#    all_trips_cleaned$ride_length
# 1  5061.3044
# 2   972.9383
# 3  4752.0504
# 4   822.3112
# 5  4561.8039
# 6   769.4416
# 7  4480.3724
# 8   711.9838
# 9  8451.6669
# 10  707.2093
# 11 6090.7373
# 12  796.7338
# 13 4950.7708
# 14  974.0730

# %% [markdown]
# Get the *number_of_rides* and average *ride_length* for every category in *member_casual* and per *weekday*.

# %%
summary_alltrips <- all_trips_cleaned %>% 
    mutate(weekday = wday(started_at, label = TRUE)) %>%    # creates weekday field using wday()
    group_by(member_casual, weekday) %>%                    # groups by usertype and weekday
            summarise(number_of_rides = n(),                # calculates the number of rides and average duration 
            average_duration = mean(ride_length)) %>% 		# calculates the average duration
    arrange(member_casual, weekday)							# sorts the records

head(summary_alltrips)
# Out:
# `summarise()` has grouped output by 'member_casual'. You can override using the
# `.groups` argument.
#   member_casual weekday number_of_rides average_duration
# 1 casual        Sun     18652           5061.304
# 2 casual        Mon      5591           4752.050
# 3 casual        Tue      7311           4561.804
# 4 casual        Wed      7690           4480.372
# 5 casual        Thu      7147           8451.667
# 6 casual        Fri      8013           6090.737

# %% [markdown]
# Write the data into a csv file. The csv file will be used for visualization in Tableau.

# %%
write.csv(summary_alltrips, file = 'summary_all_trips.csv')

# %% [markdown]
# ### Data Visualization and Analysis:
#
# For data visualization, Tableau was used. Data visualization for this case study may be accessed in [my tableau profile](https://public.tableau.com/views/CyclisticPortfolio/Dashboard1?:language=en-US&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link) or shown in the image below.
#
# ![](./cyclistic_data_viz.png)
